# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
# import sys
# import os
# sys.path.insert(0, '..') # .ipynb
# sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname(__file__), '..'))) # .py

from cfdpy.poisson import poisson2

# %% [markdown]
# # Poisson's equation
#
# ## 2次元
#
# $$
# \frac{\partial^2 p}{\partial x^2} + \frac{\partial^2 p}{\partial y^2} = \
# \frac{\partial u}{\partial x} + \frac{\partial v}{\partial y}
# $$

# %%
lx = 2 * np.pi
ly = 2 * np.pi
nx = 64
ny = 64
dx = lx / nx
dy = ly / ny
x = np.linspace(0, lx, nx, endpoint=False)
y = np.linspace(0, ly, ny, endpoint=False)
X, Y = np.meshgrid(x, y)

u = np.sin(X) * np.sin(Y)
v = np.sin(X) * np.sin(Y)

# %%
### Solve
solver = poisson2(nx, ny, dx, dy)
p = solver.solve(u, v)

### Plot
fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, dpi=150)
ax.plot_surface(X, Y, p, cmap=cm.coolwarm, linewidth=0, antialiased=False)
ax.set_xlabel("$x$")
ax.set_ylabel("$y$")
ax.set_zlabel("$p$")
plt.show()
